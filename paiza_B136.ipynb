# %%
# 入力
N = 3
H = 3
W = 3
sy = 2
sx = 1
move = 'FRB'
C = [[3,6,2],[0,4,1],[5,0,7]]

# %%
# 入力
N = 7
H = 2
W = 4
sy = 2
sx = 3
move = 'RFLLLBR'
C = [[0,1,2,3],[4,5,0,7]]

# %%
move_list = list(move)
move_list
# Out:
# ['R', 'F', 'L', 'L', 'L', 'B', 'R']

# %%
C_init = C[sy-1][sx-1]
C_init
# Out:
# 5

# %%
output = []
for i in move_list:
    if i == 'F':
        sy -= 1
        output.append(C[sy -1][sx - 1])
    elif i == 'B':
        sy += 1
        output.append(C[sy -1][sx - 1])
    elif i == 'L':
        sx -= 1
        output.append(C[sy -1][sx - 1])
    else:
        sx += 1
        output.append(C[sy -1][sx - 1])
output
# Out:
# [7, 3, 2, 1, 0, 4, 5]

# %%
C[0][1]
# Out:
# 6
