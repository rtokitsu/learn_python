# %%
# 入力
N = 6

#W = [
#    'coin'
#    ,'come'
#    ,'creation'
#    ,'economic'
#    ,'rate'
#    ,'reaction'
#]

# W = [
#     'meat'
#     ,'teammate'
# ]

W = [
    'a'
    ,'aa'
    ,'aaa'
    ,'aaaa'
]


# w1 = 'coin'
# w2 = 'come'
# w3 = 'creation'
# w4 = 'economic'
# w5 = 'rate'
# w6 = 'reaction'

# %%
W_list = []
for i in W:
    W_list.append(sorted(list(i)))
W_list
# Out:
# [['a'], ['a', 'a'], ['a', 'a', 'a'], ['a', 'a', 'a', 'a']]

# %%
W_combo = []
for i in W_list:
    for j in W_list:
        if i >= j:
            W_combo.append(sorted(i+j))
W_combo
# Out:
# [['a', 'a'],
#  ['a', 'a', 'a'],
#  ['a', 'a', 'a', 'a'],
#  ['a', 'a', 'a', 'a'],
#  ['a', 'a', 'a', 'a', 'a'],
#  ['a', 'a', 'a', 'a', 'a', 'a'],
#  ['a', 'a', 'a', 'a', 'a'],
#  ['a', 'a', 'a', 'a', 'a', 'a'],
#  ['a', 'a', 'a', 'a', 'a', 'a', 'a'],
#  ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']]

# %%
len(W_combo)
# Out:
# 10

# %%
count = 0
for i in W_combo:
    if i in sorted(W_list):
        count += W_list.count(i)
count
# Out:
# 4

# %%
sorted(W_list)
# Out:
# [['a'], ['a', 'a'], ['a', 'a', 'a'], ['a', 'a', 'a', 'a']]
