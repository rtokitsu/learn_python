# %%
import numpy as np

# %%
# 入力
stamp_1 = [
        ['abc'],
        ['def']
        ]
stamp_2 = [
        ['ghi'],
        ['jkl']
        ]
plan =  [
        [1,2,1],
        [2,1,2],
        [1,2,1]
        ]
H = 2
R = 3
C = 3

# %%
# 配置
output = [["" for i in range(C)] for i in range(H*R)]

for r in range(R):
    for c in range(C):
        stamp = globals()[f'stamp_{plan[r][c]}'] #スタンプ取得
        for h in range(H):
            output[r * H + h][c] = stamp[h][0]
output_final = ["".join(row) for row in output]
for row in output_final:
    print(row)
# Out:
# abcghiabc
# defjkldef
# ghiabcghi
# jkldefjkl
# abcghiabc
# defjkldef
